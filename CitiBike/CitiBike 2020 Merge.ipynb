# %%
#Dependences 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Take in all of our CitiBike data and read it into pandas
jan_2020 = "../Resources/JC-202001-citibike-tripdata.csv"
feb_2020 = "../Resources/JC-202002-citibike-tripdata.csv"
mar_2020 = "../Resources/JC-202003-citibike-tripdata.csv"
apr_2020 = "../Resources/JC-202004-citibike-tripdata.csv"
may_2020 = "../Resources/JC-202005-citibike-tripdata.csv"
jun_2020 = "../Resources/JC-202006-citibike-tripdata.csv"
jul_2020 = "../Resources/JC-202007-citibike-tripdata.csv"
aug_2020 = "../Resources/JC-202008-citibike-tripdata 2.csv"

jan_2020_df = pd.read_csv(jan_2020)
feb_2020_df = pd.read_csv(feb_2020)
mar_2020_df = pd.read_csv(mar_2020)
apr_2020_df = pd.read_csv(apr_2020)
may_2020_df = pd.read_csv(may_2020)
jun_2020_df = pd.read_csv(jun_2020)
jul_2020_df = pd.read_csv(jul_2020)
aug_2020_df = pd.read_csv(aug_2020)
jul_2020_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1              1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2               786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3              1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4              2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
# ...             ...                       ...                       ...
# 38675          1003  2020-07-31 23:51:37.3790  2020-08-01 00:08:20.6900
# 38676           165  2020-07-31 23:56:33.6770  2020-07-31 23:59:18.8610
# 38677           382  2020-07-31 23:56:55.9860  2020-08-01 00:03:18.8390
# 38678           674  2020-07-31 23:57:58.0150  2020-08-01 00:09:12.0420
# 38679          1007  2020-07-31 23:58:06.3070  2020-08-01 00:14:53.3340
#
#        start station id          start station name  start station latitude  \
# 0                  3694              Jackson Square               40.711130
# 1                  3791  Hoboken Ave at Monmouth St               40.735208
# 2                  3792  Columbus Dr at Exchange Pl               40.716870
# 3                  3677                Glenwood Ave               40.727551
# 4                  3191                    Union St               40.718211
# ...                 ...                         ...                     ...
# 38675              3792  Columbus Dr at Exchange Pl               40.716870
# 38676              3198            Heights Elevator               40.748716
# 38677              3209                Brunswick St               40.724176
# 38678              3185                   City Hall               40.717733
# 38679              3211                  Newark Ave               40.721525
#
#        start station longitude  end station id         end station name  \
# 0                   -74.078900            3276         Marin Light Rail
# 1                   -74.046964            3202             Newport PATH
# 2                   -74.032810            3225    Baldwin at Montgomery
# 3                   -74.071061            3194          McGinley Square
# 4                   -74.083639            3193             Lincoln Park
# ...                        ...             ...                      ...
# 38675               -74.032810            3277  Communipaw & Berry Lane
# 38676               -74.040443            3196           Riverview Park
# 38677               -74.050656            3275           Columbus Drive
# 38678               -74.043845            3185                City Hall
# 38679               -74.046305            3209             Brunswick St
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 0                 40.714584             -74.042817   42579    Customer
# 1                 40.727224             -74.033759   42564  Subscriber
# 2                 40.723659             -74.064194   42219  Subscriber
# 3                 40.725340             -74.067622   44424  Subscriber
# 4                 40.724605             -74.078406   42186  Subscriber
# ...                     ...                    ...     ...         ...
# 38675             40.714358             -74.066611   42145  Subscriber
# 38676             40.744319             -74.043991   44334  Subscriber
# 38677             40.718355             -74.038914   42154  Subscriber
# 38678             40.717733             -74.043845   45366    Customer
# 38679             40.724176             -74.050656   42139  Subscriber
#
#        birth year  gender
# 0            1969       0
# 1            1965       1
# 2            1994       1
# 3            1995       2
# 4            1993       1
# ...           ...     ...
# 38675        1977       1
# 38676        1991       1
# 38677        1984       1
# 38678        1994       2
# 38679        1982       1
#
# [38680 rows x 15 columns]

# %%
# combine into one DF
combined2020_CitiBike_df = pd.merge(jan_2020_df, feb_2020_df, how='outer')
combined2020_CitiBike_df
combined2020_CitiBike_df3 = pd.merge(combined2020_CitiBike_df, mar_2020_df, how='outer')
combined2020_CitiBike_df3
combined2020_CitiBike_df4 = pd.merge(combined2020_CitiBike_df3, apr_2020_df, how='outer')
combined2020_CitiBike_df4
combined2020_CitiBike_df5 = pd.merge(combined2020_CitiBike_df4, may_2020_df, how='outer')
combined2020_CitiBike_df5
combined2020_CitiBike_df6 = pd.merge(combined2020_CitiBike_df5, jun_2020_df, how='outer')
combined2020_CitiBike_df6
combined2020_CitiBike_df7 = pd.merge(combined2020_CitiBike_df6, jul_2020_df, how='outer')
combined2020_CitiBike_df7
combined2020_CitiBike_df8 = pd.merge(combined2020_CitiBike_df7, aug_2020_df, how='outer')
combined2020_CitiBike_df8
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 219909           162  2020-08-31 23:43:15.8540  2020-08-31 23:45:58.4550
# 219910           400  2020-08-31 23:46:19.9130  2020-08-31 23:53:00.3610
# 219911           288  2020-08-31 23:47:16.8680  2020-08-31 23:52:05.5550
# 219912           199  2020-08-31 23:50:37.2650  2020-08-31 23:53:56.9490
# 219913           333  2020-08-31 23:55:30.8050  2020-09-01 00:01:04.4110
#
#         start station id start station name  start station latitude  \
# 0                   3186      Grove St PATH               40.719586
# 1                   3186      Grove St PATH               40.719586
# 2                   3186      Grove St PATH               40.719586
# 3                   3195            Sip Ave               40.730897
# 4                   3186      Grove St PATH               40.719586
# ...                  ...                ...                     ...
# 219909              3186      Grove St PATH               40.719586
# 219910              3481            York St               40.716490
# 219911              3195            Sip Ave               40.730897
# 219912              3195            Sip Ave               40.730897
# 219913              3211         Newark Ave               40.721525
#
#         start station longitude  end station id  end station name  \
# 0                    -74.043117            3211        Newark Ave
# 1                    -74.043117            3269   Brunswick & 6th
# 2                    -74.043117            3269   Brunswick & 6th
# 3                    -74.063913            3280       Astor Place
# 4                    -74.043117            3276  Marin Light Rail
# ...                         ...             ...               ...
# 219909               -74.043117            3279       Dixon Mills
# 219910               -74.041050            3187         Warren St
# 219911               -74.063913            3194   McGinley Square
# 219912               -74.063913            3194   McGinley Square
# 219913               -74.046305            3270   Jersey & 6th St
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 0                  40.721525             -74.046305   29444  Subscriber
# 1                  40.726012             -74.050389   26305  Subscriber
# 2                  40.726012             -74.050389   29268    Customer
# 3                  40.719282             -74.071262   29278    Customer
# 4                  40.714584             -74.042817   29276  Subscriber
# ...                      ...                    ...     ...         ...
# 219909             40.721630             -74.049968   44787  Subscriber
# 219910             40.721124             -74.038051   19153  Subscriber
# 219911             40.725340             -74.067622   42434  Subscriber
# 219912             40.725340             -74.067622   44226  Subscriber
# 219913             40.725289             -74.045572   42437  Subscriber
#
#         birth year  gender
# 0             1984       2
# 1             1989       2
# 2             1989       1
# 3             1969       0
# 4             1983       2
# ...            ...     ...
# 219909        1977       1
# 219910        1986       1
# 219911        1960       1
# 219912        1994       1
# 219913        1984       2
#
# [219914 rows x 15 columns]

# %%
combined2020_CitiBike_df8["gender"] = combined2020_CitiBike_df8["gender"].map(str)
combined2020_CitiBike_df8["gender"] = combined2020_CitiBike_df8["gender"].replace(['0','1','2'],['Unknown','Male','Female'])
combined2020_CitiBike_df8
combined2020_CitiBike_df8 = combined2020_CitiBike_df8.rename(columns = {"tripduration": "tripduration (seconds)"})
combined2020_CitiBike_df8
# Out:
#         tripduration (seconds)                 starttime  \
# 0                          226  2020-01-01 00:04:50.1920
# 1                          377  2020-01-01 00:16:01.6700
# 2                          288  2020-01-01 00:17:33.8770
# 3                          435  2020-01-01 00:32:05.9020
# 4                          231  2020-01-01 00:46:19.6780
# ...                        ...                       ...
# 219909                     162  2020-08-31 23:43:15.8540
# 219910                     400  2020-08-31 23:46:19.9130
# 219911                     288  2020-08-31 23:47:16.8680
# 219912                     199  2020-08-31 23:50:37.2650
# 219913                     333  2020-08-31 23:55:30.8050
#
#                         stoptime  start station id start station name  \
# 0       2020-01-01 00:08:37.0370              3186      Grove St PATH
# 1       2020-01-01 00:22:19.0800              3186      Grove St PATH
# 2       2020-01-01 00:22:22.4420              3186      Grove St PATH
# 3       2020-01-01 00:39:21.0660              3195            Sip Ave
# 4       2020-01-01 00:50:11.3440              3186      Grove St PATH
# ...                          ...               ...                ...
# 219909  2020-08-31 23:45:58.4550              3186      Grove St PATH
# 219910  2020-08-31 23:53:00.3610              3481            York St
# 219911  2020-08-31 23:52:05.5550              3195            Sip Ave
# 219912  2020-08-31 23:53:56.9490              3195            Sip Ave
# 219913  2020-09-01 00:01:04.4110              3211         Newark Ave
#
#         start station latitude  start station longitude  end station id  \
# 0                    40.719586               -74.043117            3211
# 1                    40.719586               -74.043117            3269
# 2                    40.719586               -74.043117            3269
# 3                    40.730897               -74.063913            3280
# 4                    40.719586               -74.043117            3276
# ...                        ...                      ...             ...
# 219909               40.719586               -74.043117            3279
# 219910               40.716490               -74.041050            3187
# 219911               40.730897               -74.063913            3194
# 219912               40.730897               -74.063913            3194
# 219913               40.721525               -74.046305            3270
#
#         end station name  end station latitude  end station longitude  bikeid  \
# 0             Newark Ave             40.721525             -74.046305   29444
# 1        Brunswick & 6th             40.726012             -74.050389   26305
# 2        Brunswick & 6th             40.726012             -74.050389   29268
# 3            Astor Place             40.719282             -74.071262   29278
# 4       Marin Light Rail             40.714584             -74.042817   29276
# ...                  ...                   ...                    ...     ...
# 219909       Dixon Mills             40.721630             -74.049968   44787
# 219910         Warren St             40.721124             -74.038051   19153
# 219911   McGinley Square             40.725340             -74.067622   42434
# 219912   McGinley Square             40.725340             -74.067622   44226
# 219913   Jersey & 6th St             40.725289             -74.045572   42437
#
#           usertype  birth year   gender
# 0       Subscriber        1984   Female
# 1       Subscriber        1989   Female
# 2         Customer        1989     Male
# 3         Customer        1969  Unknown
# 4       Subscriber        1983   Female
# ...            ...         ...      ...
# 219909  Subscriber        1977     Male
# 219910  Subscriber        1986     Male
# 219911  Subscriber        1960     Male
# 219912  Subscriber        1994     Male
# 219913  Subscriber        1984   Female
#
# [219914 rows x 15 columns]

# %%
# Display the total number of rides for 2020
count = len(combined2020_CitiBike_df8["tripduration (seconds)"])
print(f"There were a total of {count} between January 1, 2020 through August 31,2020")
# Out:
# There were a total of 219914 between January 1, 2020 through August 31,2020

# %%
# Count of male, female, and unknown
gender_type = combined2020_CitiBike_df8["gender"].value_counts()
gender_type
# Out:
# Male       129491
# Female      55578
# Unknown     34845
# Name: gender, dtype: int64

# %%
# Create a pie chart based upon use of service by gender
bike_pie = gender_type.plot(kind="pie", y=gender_type, title=("2020 Bike Service by Gender"))
bike_pie.set_ylabel("Gender")
plt.tight_layout()
plt.axis("equal")
plt.show()

# %%
# Number of rides broken down by month
jancount2020 = len(jan_2020_df["tripduration"])
jancount2020
print(f"There were a total of {jancount2020} between January 1, 2020 through January 31,2020")
febcount2020 =len(feb_2020_df["tripduration"])
febcount2020
print(f"There were a total of {febcount2020} between Febuary 1, 2020 through Febuary 29,2020")
marcount2020= len(mar_2020_df["tripduration"])
marcount2020
print(f"There were a total of {marcount2020} between March 1, 2020 through March 31,2020")
aprcount2020 = len(apr_2020_df["tripduration"])
aprcount2020
print(f"There were a total of {aprcount2020} between April 1, 2020 through April 30,2020")
maycount2020 = len(may_2020_df["tripduration"])
maycount2020
print(f"There were a total of {maycount2020} between May 1, 2020 through May 31,2020")
juncount2020 = len(jun_2020_df["tripduration"])
juncount2020
print(f"There were a total of {juncount2020} between June 1, 2020 through June 30,2020")
julcount2020 = len(jul_2020_df["tripduration"])
julcount2020
print(f"There were a total of {julcount2020} between July 1, 2020 through July 31,2020")
augcount2020 = len(aug_2020_df["tripduration"])
augcount2020
print(f"There were a total of {augcount2020} between August 1, 2020 through August 31,2020")
# Out:
# There were a total of 26020 between January 1, 2020 through January 31,2020
# There were a total of 22962 between Febuary 1, 2020 through Febuary 29,2020
# There were a total of 17719 between March 1, 2020 through March 31,2020
# There were a total of 9268 between April 1, 2020 through April 30,2020
# There were a total of 25077 between May 1, 2020 through May 31,2020
# There were a total of 36921 between June 1, 2020 through June 30,2020
# There were a total of 38680 between July 1, 2020 through July 31,2020
# There were a total of 43267 between August 1, 2020 through August 31,2020

# %%
# average trip duration broken down by month
jancount2020 = len(jan_2020_df["tripduration"])
jantripduration2020 = jan_2020_df["tripduration"].sum()
janaveragetripduration2020 = jantripduration2020/jancount2020
janaveragetripduration2020
print(f"The average trip duration for January 2020 was {janaveragetripduration2020}")

febcount2020 = len(feb_2020_df["tripduration"])
febtripduration2020 = feb_2020_df["tripduration"].sum()
febaveragetripduration2020 = febtripduration2020/febcount2020
febaveragetripduration2020
print(f"The average trip duration for Febuary 2020 was {febaveragetripduration2020}")

marcount2020 = len(mar_2020_df["tripduration"])
martripduration2020 = mar_2020_df["tripduration"].sum()
maraveragetripduration2020 = martripduration2020/marcount2020
maraveragetripduration2020

print(f"The average trip duration for March 2020 was {maraveragetripduration2020}")

aprcount2020 = len(apr_2020_df["tripduration"])
aprtripduration2020 = apr_2020_df["tripduration"].sum()
apraveragetripduration2020 = aprtripduration2020/aprcount2020
apraveragetripduration2020
print(f"The average trip duration for April 2020 was {apraveragetripduration2020}")

maycount2020 = len(may_2020_df["tripduration"])
maytripduration2020 = may_2020_df["tripduration"].sum()
mayaveragetripduration2020 = maytripduration2020/maycount2020
mayaveragetripduration2020
print(f"The average trip duration for May 2020 was {mayaveragetripduration2020}")

juncount2020 = len(jun_2020_df["tripduration"])
juntripduration2020 = jun_2020_df["tripduration"].sum()
junaveragetripduration2020 = juntripduration2020/juncount2020
junaveragetripduration2020
print(f"The average trip duration for June 2020 was {junaveragetripduration2020}")

julcount2020 = len(jul_2020_df["tripduration"])
jultripduration2020 = jul_2020_df["tripduration"].sum()
julaveragetripduration2020 = jultripduration2020/julcount2020
julaveragetripduration2020
print(f"The average trip duration for July 2020 was {julaveragetripduration2020}")

augcount2020 = len(aug_2020_df["tripduration"])
augtripduration2020 = aug_2020_df["tripduration"].sum()
augaveragetripduration2020 = augtripduration2020/augcount2020
augaveragetripduration2020
print(f"The average trip duration for August 2020 was {augaveragetripduration2020}")
# Out:
# The average trip duration for January 2020 was 540.8975403535742
# The average trip duration for Febuary 2020 was 665.6929274453445
# The average trip duration for March 2020 was 1384.5124442688639
# The average trip duration for April 2020 was 1803.6978851963747
# The average trip duration for May 2020 was 2445.721138892212
# The average trip duration for June 2020 was 2296.5872267815066
# The average trip duration for July 2020 was 1841.7221302998967
# The average trip duration for August 2020 was 1712.3783483948505

# %%
# Groupby start stations
startstation = combined2020_CitiBike_df8.groupby(["start station name"])
startstationcount = startstation["start station name"].count()
#create new DataFrame
top5_start_stations = pd.DataFrame({"start station count" : startstationcount})
#Sort the start station count column in descending order
top5_start_stations = top5_start_stations.sort_values(["start station count"], ascending = [False])
top5_start_stations.head()
# Out:
#                     start station count
# start station name
# Grove St PATH                     14762
# Newport Pkwy                      12683
# Liberty Light Rail                11646
# Hamilton Park                      9987
# Sip Ave                            8987

# %%
# Groupby end stations
endstation = combined2020_CitiBike_df8.groupby(["end station name"])
endstationcount = endstation["end station name"].count()
#create new DataFrame
top5_end_stations = pd.DataFrame({"end station count": endstationcount})
#Sort the start station count column in descending order
top5_end_stations = top5_end_stations.sort_values(["end station count"], ascending = [False])
top5_end_stations.head()
# Out:
#                             end station count
# end station name
# Grove St PATH                           17191
# Newport Pkwy                            12782
# Liberty Light Rail                      11847
# Hamilton Park                            9966
# Columbus Dr at Exchange Pl               8823

# %%
# Create bins in which to place values based upon birth year
bins = [1900, 1946, 1964, 1979, 1994, 2015]
# Create labels for these bins
bin_labels = ["1900-1945", "1946-1964", "1965-1979", "1980-1994", "1995-2015"]

#Create a new column for which been each row falls into
combined2020_CitiBike_df8["binned"] = pd.cut(combined2020_CitiBike_df8["birth year"], bins)

#Get the value count for each bin group
bin_count = pd.cut(combined2020_CitiBike_df8["birth year"], bins=bins).value_counts()

#Group by the binned column 
bin_group = combined2020_CitiBike_df8.groupby("binned")

#Print the number of values in each bin group 
print(bin_group["birth year"].count())
# Out:
# binned
# (1900, 1946]        35
# (1946, 1964]     15133
# (1964, 1979]     71616
# (1979, 1994]    115335
# (1994, 2015]     17775
# Name: birth year, dtype: int64

# %%
#Set the x and y axis
x_axis = bin_labels 
y = bin_group["birth year"].count()
#Create the bar chart 
plt.bar(x_axis, y, color = "darkturquoise")

#Set the labels and title
plt.title("Age Range of CitiBike Customers")
plt.xlabel("Age Ranges")
plt.ylabel("Number of User")
# Out:
# Text(0, 0.5, 'Number of User')

# %%
# Count of subscriber vs. customer 
combined2020_CitiBike_df8.loc[:,('birth year')] = combined2020_CitiBike_df8['birth year'].astype(int)
UT_mode = combined2020_CitiBike_df8.mode().loc[:('usertype')]
# imputing mode inplace of missing values
combined2020_CitiBike_df8['usertype'].fillna(value=UT_mode['usertype'][0], inplace=True)
# check the counts again
combined2020_CitiBike_df8['usertype'].value_counts()
# Out:
# Subscriber    150142
# Customer       69772
# Name: usertype, dtype: int64

# %%
# plot a pie chart

fig = plt.figure(figsize=(3,3), dpi=200)
ax = plt.subplot(111)
combined2020_CitiBike_df8['usertype'].value_counts().plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=270, fontsize=10)

# %%
# Top 5 most used bikes by bike id

bike_id = combined2020_CitiBike_df8.groupby(["bikeid"])
bikecount = bike_id["bikeid"].count()
#create new DataFrame
top5_bikes = pd.DataFrame({"bike id count" : bikecount})
#Sort the start station count column in descending order
top5_bikes = top5_bikes.sort_values(["bike id count"], ascending = [False])
top5_bikes.head()
# Out:
#         bike id count
# bikeid
# 42296             549
# 42545             536
# 42220             523
# 42134             522
# 42365             502

# %%
#Number of rides per month
jan_rides = len(jan_2020_df["gender"])
feb_rides = len(feb_2020_df["gender"])
mar_rides = len(mar_2020_df["gender"])
apr_rides = len(apr_2020_df["gender"])
may_rides = len(may_2020_df["gender"])
june_rides= len(jun_2020_df["gender"])
july_rides = len(jul_2020_df["gender"])
aug_rides = len(aug_2020_df["gender"])
months = {"Months": ["January","February","March","April","May","June","July","August"],
          "Count" : [jan_rides, feb_rides, mar_rides, apr_rides, may_rides, june_rides, july_rides, aug_rides]}
total_rides = pd.DataFrame(months, columns = ["Months", "Count"])
total_rides
# Out:
#      Months  Count
# 0   January  26020
# 1  February  22962
# 2     March  17719
# 3     April   9268
# 4       May  25077
# 5      June  36921
# 6      July  38680
# 7    August  43267

# %%
#Turn the total rides data frame into a line graph
x_axis = total_rides["Months"]
y_axis = total_rides["Count"]
plt.plot(x_axis, y_axis, color = "orchid")
plt.xlabel("Month")
plt.ylabel("Number of Rides")
plt.title("Number of Rides per Month")
plt.grid()
plt.show()
